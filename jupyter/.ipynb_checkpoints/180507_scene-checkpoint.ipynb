# %%
import json

json.dump({
    'width': 1920,
    'height': 1080,
    'program': {
        'vertex': '''
            precision highp float;
            attribute vec3 pos;
            // varying float value;

            void main(void) {
              gl_Position = vec4(pos, 1.0);
              gl_PointSize = 50.0;
              // value = 1.0;
            }
        ''',
        'fragment': '''
            precision highp float;
            uniform vec4 color;

            void main(void) {
            }
        ''',        
    },
    'uniforms': {
        'color': {
            'type': '4f',
            'value': [1.0, 0.5, 0.0, 1.0],
        }
    },
    'attributes': {
         'pos': {
             'type': 'Float32Array',
             'data': [
                 0, 0, 0,
                 -0.5, 0, 0,
                 0, -0.5, 0,
             ],
             'itemSize': 3,
         }
    },
    'textures': {
        'font': {
            'filter': 'NEAREST',
            'url': 'cmu_serif.png',
            'bindTo': 0,
        }
    },
    'draw': {
        'type': 'POINTS',
        'first': 0,
        'count': 3,
    },
}, open('../renderer/frame.json', 'w'))

# %%
import json

json.dump({
    'width': 1920,
    'height': 1080,
    'post_processing': {},
    'layers': [
        {
            'control': {
                'file': '',
            },
            'vertex': {
                'file': 'point_vert',
            },
            'fragment': {
                'file': 'point_frag',
            },
            'type': 'POINTS',
            'buffers': {
                'font': {
                    'type': 'Image',
                    'fname': 'cmu_serif.png',
                    'filter': 'NEAREST',
                },
                'positions': {
                    'type': 'Float32Array',
                    'size': 3,
                    'data': [
                        0, 0, 0,
                        -1, -1, 0,
                        1, -1, 0,
                    ],
                },
            },
            'uniforms': {
                'camera': [[0, 0, 0], [0, 0, 1], [0, 0, 2]]
            },
        }
    ],
}, open('../renderer/scene.json', 'w'))
